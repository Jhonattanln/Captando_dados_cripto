# %% [markdown]
# ## Dados criptos

# %% [markdown]
# ### Importando bibliotecas

# %%
import cryptocompare ### API para obtenção dos dados
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go 
import plotly.express as px
import datetime

# %% [markdown]
# ### Capitando e armazendo dados

# %%
btc = pd.DataFrame(cryptocompare.get_historical_price_day('BTC', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'BTC'}, axis=1)
eth = pd.DataFrame(cryptocompare.get_historical_price_day('ETH', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'ETH'}, axis=1)
bnb = pd.DataFrame(cryptocompare.get_historical_price_day('BNB', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'BNB'}, axis=1)
dot = pd.DataFrame(cryptocompare.get_historical_price_day('DOT', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'DOT'}, axis=1)
uni = pd.DataFrame(cryptocompare.get_historical_price_day('UNI', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'UNI'}, axis=1)
ave = pd.DataFrame(cryptocompare.get_historical_price_day('AAVE', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'AAVE'}, axis=1)
sol = pd.DataFrame(cryptocompare.get_historical_price_day('SOL', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'SOL'}, axis=1)
axs = pd.DataFrame(cryptocompare.get_historical_price_day('AXS', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'AXS'}, axis=1)
cro = pd.DataFrame(cryptocompare.get_historical_price_day('CRO', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'CRO'}, axis=1)
link = pd.DataFrame(cryptocompare.get_historical_price_day('LINK', currency='USD', exchange='CCCAGG', limit=250))[['time','close']].set_index('time').rename({'close':'LINK'}, axis=1)

# %% [markdown]
# ### Concatenando DataFrame

# %%
df = pd.concat([btc, eth, bnb, dot, uni, ave, sol, axs, cro, link], axis=1)
df.head()
# Out:
#                  BTC      ETH     BNB    DOT    UNI    AAVE    SOL    AXS  \
# time
# 1620000000  57195.07  3431.41  676.62  37.27  42.28  518.36  46.06  9.237
# 1620086400  53244.07  3241.09  610.18  34.80  43.17  448.64  42.64  8.077
# 1620172800  57506.88  3528.86  652.13  40.45  42.51  481.68  44.98  8.661
# 1620259200  56441.94  3491.74  634.41  41.57  40.23  453.38  43.51  7.913
# 1620345600  57374.33  3483.96  624.81  39.91  39.79  445.57  43.21  8.382
#
#                CRO   LINK
# time
# 1620000000  0.1874  42.08
# 1620086400  0.1660  45.58
# 1620172800  0.1832  49.60
# 1620259200  0.1890  47.19
# 1620345600  0.1892  49.21

# %% [markdown]
# ### Ajustando datas

# %%
df['Data'] = [datetime.datetime.fromtimestamp(d) for d in df.index]
#df.set_index('Data', inplace=True)
df.head()
# Out:
#                  BTC      ETH     BNB    DOT    UNI    AAVE    SOL    AXS  \
# time
# 1620000000  57195.07  3431.41  676.62  37.27  42.28  518.36  46.06  9.237
# 1620086400  53244.07  3241.09  610.18  34.80  43.17  448.64  42.64  8.077
# 1620172800  57506.88  3528.86  652.13  40.45  42.51  481.68  44.98  8.661
# 1620259200  56441.94  3491.74  634.41  41.57  40.23  453.38  43.51  7.913
# 1620345600  57374.33  3483.96  624.81  39.91  39.79  445.57  43.21  8.382
#
#                CRO   LINK                Data
# time
# 1620000000  0.1874  42.08 2021-05-02 21:00:00
# 1620086400  0.1660  45.58 2021-05-03 21:00:00
# 1620172800  0.1832  49.60 2021-05-04 21:00:00
# 1620259200  0.1890  47.19 2021-05-05 21:00:00
# 1620345600  0.1892  49.21 2021-05-06 21:00:00

# %%
pct = pd.DataFrame()
for i in df[['BTC', 'ETH','BNB', 'DOT', 'UNI', 'AAVE', 'SOL', 'AXS', 'LINK']]:
    pct[i] = df[i].div(df[i].iloc[0])
pct['Data'] = df['Data']
pct.head()
# Out:
#                  BTC       ETH       BNB       DOT       UNI      AAVE  \
# time
# 1620000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1620086400  0.930921  0.944536  0.901806  0.933727  1.021050  0.865499
# 1620172800  1.005452  1.028399  0.963805  1.085323  1.005440  0.929238
# 1620259200  0.986832  1.017582  0.937616  1.115374  0.951514  0.874643
# 1620345600  1.003134  1.015314  0.923428  1.070834  0.941107  0.859576
#
#                  SOL       AXS      LINK                Data
# time
# 1620000000  1.000000  1.000000  1.000000 2021-05-02 21:00:00
# 1620086400  0.925749  0.874418  1.083175 2021-05-03 21:00:00
# 1620172800  0.976552  0.937642  1.178707 2021-05-04 21:00:00
# 1620259200  0.944637  0.856663  1.121435 2021-05-05 21:00:00
# 1620345600  0.938124  0.907437  1.169439 2021-05-06 21:00:00

# %% [markdown]
# ### Plotando Gráficos com Plotly

# %%
fig = px.line(pct, x='Data', y=pct.columns,
        hover_data={'Data':'|%B %d, %Y'},
        title='Criptos')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %% [markdown]
# ### Analizando fontes dos dados

# %%
data = cryptocompare.get_exchanges()
#data = pd.DataFrame(data)
data.keys()
# Out:
# dict_keys(['HADAX', 'Minebit', 'Bitinfi', 'Ironex', 'BitMarket', 'Abucoins', 'TradeSatoshi', 'DDEX', 'WorldCryptoCap', 'FCoin', 'DEx', 'Zecoex', 'Nlexch', 'Ore', 'TDAX', 'FCCE', 'InstantBitex', 'IQFinex', 'everbloom', 'incorex', 'StocksExchangeio', 'smartrade', 'altilly', 'bitspark', 'Binanceje', 'chainrift', 'coinzest', 'bingcoins', 'oex', 'onederx', 'darbfinance', 'exscudo', 'Gneiss', 'VBTC', 'binanceusa', 'huobijapan', 'BitexBook', 'RightBTC', 'EXRATES', 'Paymium', 'BTCAlpha', 'LBank', 'seedcx', 'e55com', 'chaoex', 'sistemkoin', 'tokok', 'tokensnet', 'paribu', 'binancedex', 'uniswap', 'zebitex', 'ftx', 'decoin', 'Binance', 'BTCE', 'OKCoin', 'BTER', 'Bitfinex', 'Cexio', 'Yacuna', 'Coinbase', 'LocalBitcoins', 'itBit', 'HitBTC', 'BTC38', 'BTCExchange', 'hbus', 'LakeBTC', 'Bit2C', 'Coinsetter', 'CCEX', 'Coinse', 'MonetaGo', 'Gatecoin', 'Yunbi', 'WavesDEX', 'CCEDK', 'Cryptopia', 'Exmo', 'Yobit', 'BitBay', 'Korbit', 'BTCMarkets', 'Coincheck', 'Vaultoro', 'MercadoBitcoin', 'Unocoin', 'Bitso', 'BTCXIndia', 'TheRockTrading', 'Quoine', 'Liqui', 'Luno', 'CryptoX', 'TuxExchange', 'CHBTC', 'LiveCoin', 'Tidex', 'Coinone', 'EthexIndia', 'Surbitcoin', 'Bithumb', 'Foxbit', 'Zaif', 'Jubi', 'ViaBTC', 'Novaexchange', 'Lykke', 'Coinroom', 'BXinth', 'HuobiPro', 'OKEX', 'Gateio', 'trustdex', 'BitGrail', 'BitFlip', 'Coincap', 'ChileBit', 'Velox', 'LAToken', 'TokenStore', 'Ethfinex', 'DSX', 'Coinnest', 'Bitlish', 'Buda', 'Upbit', 'uniswapv3', 'Blackturtle', 'BitBank', 'CoinDeal', 'AidosMarket', 'CoinsBank', 'BTCTurk', 'BitMart', 'Bibox', 'ZB', 'SingularityX', 'Simex', 'Nebula', 'Bluebelt', 'ABCC', 'OpenLedger', 'WEX', 'cryptocarbon', 'BigONE', 'CoinBene', 'Kuna', 'Tokenomy', 'IDAX', 'CoinHub', 'Nexchange', 'Hikenex', 'Bitstamp', 'BitTrex', 'Qryptos', 'BTCBOX', 'IndependentReserve', 'Bitmex', 'Codex', 'Kraken', 'Globitex', 'CoinJar', 'CoinFalcon', 'ACX', 'Cryptonit', 'CoinPulse', 'bkex', 'Bitforex', 'BCEX', 'Liquid', 'P2PB2B', 'iCoinbay', 'CoinTiger', 'Threexbit', 'Bitkub', 'NDAX', 'DigiFinex', 'Coinmate', 'Gnosis', 'Nuex', 'ethermium', 'Catex', 'Exenium', 'ZBG', 'SafeCoin', 'XS2', 'bw', 'coinsuper', 'CryptoExchangeWS', 'alphaex', 'bybit', 'Bitpoint', 'Poloniex', 'Bgogo', 'xena', 'aliexchange', 'fatbtc', 'coss', 'eidoo', 'idevex', 'crex24', 'gopax', 'coinfield', 'coinall', 'bitci', 'primexbt', 'ataix', 'zloadr', 'thore', 'CBX', 'unnamed', 'coineal', 'dcoin', 'coinegg', 'bitasset', 'tchapp', 'bilaxy', 'aax', 'cryptonex', 'lmax', 'compound', 'timex', 'indodax', 'bitpanda', 'etoro', 'sigenpro', 'bitfex', 'coinspro', 'slicex', 'bequant', 'xbtpro', 'uniswapv2', 'bithumbglobal', 'btse', 'btcmex', 'valr', 'equos', 'anycoindirect', 'probit', 'mycoinstory', 'sigenp2p', 'bitbuy', 'nominex', 'PlutusDEX', 'betconix', 'ftxus', 'beldex', 'BitSquare', 'crosstower', 'xcoex', 'raidofinance', 'CoinCorner', 'Gemini', 'EtherDelta', 'IDEX', 'CoinEx', 'Neraex', 'CryptoBulls', 'Bitsane', 'StocksExchange', 'cobinhood', 'bitshares', 'Braziliex', 'Remitano', 'cryptodotcom', 'sushiswap', 'EXX', 'bitmax', 'bhex', 'pancakeswap', 'oneinch', 'xtpub', 'curve', 'trxmarket', 'Switcheo', 'wbb', 'chainx', 'bcbitcoin', 'ExtStock', 'biki', 'Liqnet', 'BitZ', 'Bleutrade', 'Coinsbit', 'bitcoincom', 'huobikorea', 'Coinfloor', 'blockchaincom', 'bitFlyer', 'bitflyerus', 'bitFlyerFX', 'bitflyereu', 'Kucoin', 'currency', 'Graviex'])

# %% [markdown]
# ### Criando o banco de dados

# %%
### Importando sqlalchemy para a conectar o MySQL
from sqlalchemy import create_engine

# %%
### Criando conexão
my_conection = create_engine('mysql+pymysql://root:Zurique@localhost:3306/cripto')

# %%
### Criando o banco de dados no MySQL Workbench
df.to_sql(con=my_conection, name='cripto', if_exists='append')

# %%
df.head()
# Out:
#                  BTC      ETH     BNB    DOT    UNI    AAVE    SOL    AXS  \
# time
# 1620000000  57195.07  3431.41  676.62  37.27  42.28  518.36  46.06  9.237
# 1620086400  53244.07  3241.09  610.18  34.80  43.17  448.64  42.64  8.077
# 1620172800  57506.88  3528.86  652.13  40.45  42.51  481.68  44.98  8.661
# 1620259200  56441.94  3491.74  634.41  41.57  40.23  453.38  43.51  7.913
# 1620345600  57374.33  3483.96  624.81  39.91  39.79  445.57  43.21  8.382
#
#                CRO   LINK                Data
# time
# 1620000000  0.1874  42.08 2021-05-02 21:00:00
# 1620086400  0.1660  45.58 2021-05-03 21:00:00
# 1620172800  0.1832  49.60 2021-05-04 21:00:00
# 1620259200  0.1890  47.19 2021-05-05 21:00:00
# 1620345600  0.1892  49.21 2021-05-06 21:00:00
